# %% [markdown]
# <a href="https://colab.research.google.com/github/molluIdontknow/ELE_Algorithm/blob/%EA%B9%80%EC%8B%9C%EC%9A%B0/Data_cleaning_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import from drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # R-Stats

# %%
SCRIPT = "/content/q_feature_extractor_v2.py"
DATA_ROOT = "/content/drive/MyDrive/Battery raw data"
OUTPUT = "/content/drive/MyDrive/q_features_25C.csv"
REJECTED = "/content/drive/MyDrive/q_features_25C_rejected.csv"

# !python "{SCRIPT}" "{DATA_ROOT}" \
    -o "{OUTPUT}" \
    --rejected "{REJECTED}" \
    --include-regex "25°C"
# Out:
# python3: can't open file '/content/q_feature_extractor_v2.py': [Errno 2] No such file or directory

# %% [markdown]
# # DCIR

# %%
# !python "/content/dcir_feature_extractor_v2.py" \
    "/content/drive/MyDrive/Battery raw data" \
    -o "/content/drive/MyDrive/dcir_features_25C.csv" \
    --rejected "/content/drive/MyDrive/dcir_features_25C_rejected.csv" \
    --window-start 8 \
    --window-end 10 \
    --project-mode discharge \
    --include-regex "25"
# Out:
# accepted RPT samples: 149
# rejected RPT samples: 0
# DCIR window: 8–10 s
# project mode: discharge
# output: /content/drive/MyDrive/dcir_features_25C.csv

# %% [markdown]
# # Time Features

# %%
SCRIPT = "/content/time_feature_extractor.py"
DATA_ROOT = "/content/drive/MyDrive/Battery raw data"

OUTPUT = "/content/drive/MyDrive/time_features_25C.csv"
REJECTED = "/content/drive/MyDrive/time_features_25C_rejected.csv"

# !python "{SCRIPT}" "{DATA_ROOT}" \
    -o "{OUTPUT}" \
    --rejected "{REJECTED}" \
    --include-regex "25" \
    --cccv-rate 1C
# Out:
# accepted RPT samples: 149
# rejected RPT samples: 0
# output: /content/drive/MyDrive/time_features_25C.csv

# %% [markdown]
# # Merge

# %%
# !python "/content/merge_feature_datasets.py" \
    --q "/content/drive/MyDrive/q_features_25C.csv" \
    --dcir "/content/drive/MyDrive/dcir_features_25C.csv" \
    --time "/content/drive/MyDrive/time_features_25C.csv" \
    -o "/content/drive/MyDrive/merged_features_25C.csv" \
    --temperature 25 \
    --strict-keys
# Out:
# Q: temperature filter 25°C -> 141 kept, 0 removed
# DCIR: temperature filter 25°C -> 141 kept, 8 removed
# TIME: temperature filter 25°C -> 141 kept, 8 removed
# DCIR: window_start_s = 8.0
# DCIR: window_end_s = 10.0
# DCIR: project_mode = discharge
# TIME: cccv_rate_used = 1C
# Q keys:     141
# DCIR keys:  141
# TIME keys:  141
# Common keys:141
# Output rows: 141
# Output columns: 29
# Saved: /content/drive/MyDrive/merged_features_25C.csv
